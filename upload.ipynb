# %%
import pandas as pd
import redis

# connect to redis

r = redis.Redis(
  host='helpful-mako-37953.upstash.io',
  port=6379,
  password='AZRBAAIncDEzNDZlNjU0YTViNDE0YmE4YmQ4YWJkZjE1MjU3ZmU2NnAxMzc5NTM',
  ssl=True
)

# %%
df=pd.read_excel("./bookdatas/書籍測試.xlsx")
print(r.hgetall('book:9780060850524'))
# for i in range (len(df)):
# print(df)
# Out:
# {b'cover': b'brave_new_world_cover_url', b'name': b'Brave New World', b'book_id': b'2'}
